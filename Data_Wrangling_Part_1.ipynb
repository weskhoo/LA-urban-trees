# %% [markdown]
# # **Data Wrangling (Part 1) Los Angeles County Urban Trees**
#
# **Summary**
#
# The purpose of this notebook is to clean raw urban trees data. The notebook shows the steps taken to prepare the raw dataset for exploratory data analysis and statistical analysis. A brief summary of the content of this notebook is below:
#
# **Importing Data**
#
# LA county data on urban trees were imported from https://github.com/stiles/data/tree/master/los-angeles-street-trees
#
# **Cleaning Data**
#
# Urban trees Data (Starting with 1.7 Million Trees)
#
# i. Removing counties dataset which has inaccurate geometry information. (49K Trees)
#
# ii. Removing columns with 100% missing values.
#
# iii. Exporting to CSV to reduce Google Colab RAM usage

# %%
#This notebook is done google colab.

#Mounting your google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Importing relevant packages
import pandas as pd
import requests
from bs4 import BeautifulSoup

# !pip install geopandas
import geopandas as gpd
# Out:
# Collecting geopandas
#   Downloading https://files.pythonhosted.org/packages/f7/a4/e66aafbefcbb717813bf3a355c8c4fc3ed04ea1dd7feb2920f2f4f868921/geopandas-0.8.1-py2.py3-none-any.whl (962kB)
#      |████████████████████████████████| 972kB 2.2MB/s
# Collecting pyproj>=2.2.0
#   Downloading https://files.pythonhosted.org/packages/e4/ab/280e80a67cfc109d15428c0ec56391fc03a65857b7727cf4e6e6f99a4204/pyproj-3.0.0.post1-cp36-cp36m-manylinux2010_x86_64.whl (6.4MB)
#      |████████████████████████████████| 6.5MB 21.2MB/s
# Collecting fiona
#   Downloading https://files.pythonhosted.org/packages/36/8b/e8b2c11bed5373c8e98edb85ce891b09aa1f4210fd451d0fb3696b7695a2/Fiona-1.8.17-cp36-cp36m-manylinux1_x86_64.whl (14.8MB)
#      |████████████████████████████████| 14.8MB 308kB/s
# Requirement already satisfied: shapely in /usr/local/lib/python3.6/dist-packages (from geopandas) (1.7.1)
# Requirement already satisfied: pandas>=0.23.0 in /usr/local/lib/python3.6/dist-packages (from geopandas) (1.1.4)
# Requirement already satisfied: certifi in /usr/local/lib/python3.6/dist-packages (from pyproj>=2.2.0->geopandas) (2020.6.20)
# Collecting munch
#   Downloading https://files.pythonhosted.org/packages/cc/ab/85d8da5c9a45e072301beb37ad7f833cd344e04c817d97e0cc75681d248f/munch-2.5.0-py2.py3-none-any.whl
# Requirement already satisfied: click<8,>=4.0 in /usr/local/lib/python3.6/dist-packages (from fiona->geopandas) (7.1.2)
# Requirement already satisfied: attrs>=17 in /usr/local/lib/python3.6/dist-packages (from fiona->geopandas) (20.2.0)
# Requirement already satisfied: six>=1.7 in /usr/local/lib/python3.6/dist-packages (from fiona->geopandas) (1.15.0)
# Collecting cligj>=0.5
#   Downloading https://files.pythonhosted.org/packages/ba/06/e3440b1f2dc802d35f329f299ba96153e9fcbfdef75e17f4b61f79430c6a/cligj-0.7.0-py3-none-any.whl
# Collecting click-plugins>=1.0
#   Downloading https://files.pythonhosted.org/packages/e9/da/824b92d9942f4e472702488857914bdd50f73021efea15b4cad9aca8ecef/click_plugins-1.1.1-py2.py3-none-any.whl
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.23.0->geopandas) (1.18.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.23.0->geopandas) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.23.0->geopandas) (2.8.1)
# Installing collected packages: pyproj, munch, cligj, click-plugins, fiona, geopandas
# Successfully installed click-plugins-1.1.1 cligj-0.7.0 fiona-1.8.17 geopandas-0.8.1 munch-2.5.0 pyproj-3.0.0.post1

# %%
#Urban trees data are stored separately according to 50 counties of Los Angeles.
#Big thank you to Matt Stiles for the urban trees data.

#Here we scrape all the file names that contains the urban tree data using BeautifulSoup.
page = requests.get(f'https://github.com/stiles/data/tree/master/los-angeles-street-trees/all')
soup = BeautifulSoup(page.content, 'html.parser')
container = soup.find(id="js-repo-pjax-container")
title_tag = container.select("[title]")
titles = [pt.get_text() for pt in title_tag]
titles = titles[8:]

#Cleaning the list of scrape names
titles.remove("script.sh")
titles.remove("updates to trump tweets")
titles.remove("\n.\u200a.\n")

#pasadena is removed from this list because of conflicting column names. We will deal with this later.
titles.remove("pasadena.geojson") 

#Viewing number of total files (should be 49)
print(len(titles))
# Out:
# 49

# %%
#Creating an empty pandas dataframe
treesdf = pd.DataFrame()

#Looping through the list of file names and merging the geojson files into one pandas dataframe
for title in titles:
  url = f"https://github.com/stiles/data/blob/master/los-angeles-street-trees/all/{title}?raw=True"
  #Opening a geojson file as a pandas dataframe
  onecitydf = gpd.read_file(url)
  #Adding a column to reflect the respective county of the dataset
  onecitydf["whichcity"] = title
  #Cleaning the column names
  onecitydf.columns = onecitydf.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')
  #Data from 'lat','lon','objectid' were saved in different formats in different datasets. Here they were removed so that datasets can be merged without issues.
  if 'lat' in onecitydf.columns:
    onecitydf = onecitydf.drop('lat',axis=1)
  if 'lon' in onecitydf.columns:
    onecitydf = onecitydf.drop('lon',axis=1)
  if 'objectid' in onecitydf.columns:
    onecitydf = onecitydf.drop('objectid',axis=1)
  treesdf = treesdf.append(onecitydf)
  print(f"Done with {title}")
# Out:
# Done with agoura-hills.geojson
# Done with alhambra.geojson
# Done with arcadia.geojson
# Done with artesia.geojson
# Done with bell-gardens.geojson
# Done with bellflower.geojson
# Done with beverly-hills.geojson
# Done with burbank.geojson
# Done with carson.geojson
# Done with cerritos.geojson
# Done with covina.geojson
# Done with culver-city.geojson
# Done with diamond-bar.geojson
# Done with downey.geojson
# Done with duarte.geojson
# Done with el-monte.geojson
# Done with el-segundo.geojson
# Done with glendale.geojson
# Done with glendora.geojson
# Done with inglewood.geojson
# Done with la-mirada.geojson
# Done with la-verne.geojson
# Done with lancaster.geojson
# Done with lawndale.geojson
# Done with lomita.geojson
# Done with long-beach.geojson
# Done with los-angeles-city.geojson
# Done with los-angeles-county.geojson
# Done with malibu.geojson
# Done with mandarin-orange-trees.geojson
# Done with paramount.geojson
# Done with pomona.geojson
# Done with rancho-palos-verdes.geojson
# Done with redondo-beach.geojson
# Done with san-dimas.geojson
# Done with san-fernando.geojson
# Done with san-gabriel.geojson
# Done with san-marino.geojson
# Done with santa-clarita-parks.geojson
# Done with santa-clarita.geojson
# Done with santa-fe-springs.geojson
# Done with santa-monica.geojson
# Done with simi-valley.geojson
# Done with south-gate.geojson
# Done with south-pasadena.geojson
# Done with temple-city.geojson
# Done with walnut.geojson
# Done with west-hollywood.geojson
# Done with whittier.geojson

# %%
#Here we fix the issues with pasadena so it can be merged with the treesdf
url = 'https://github.com/stiles/data/blob/master/los-angeles-street-trees/all/pasadena.geojson?raw=True'
pasadena = gpd.read_file(url)

#Cleaning the columns
pasadena["botanical"] = pasadena["Genus"] + " " + pasadena["Species"]
pasadena = pasadena.drop(['Genus','Species'],axis=1)
#Adding a column to reflect the respective county of the dataset
pasadena["whichcity"] = "pasadena.geojson"
#Cleaning the column names
pasadena.columns = pasadena.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')
#Data from 'lat','lon','objectid' were saved in different formats in different datasets. Here they were removed so that datasets can be merged without issues.
if 'lat' in pasadena.columns:
  pasadena = pasadena.drop('lat',axis=1)
if 'lon' in pasadena.columns:
  pasadena = pasadena.drop('lon',axis=1)
if 'objectid' in pasadena.columns:
  pasadena = pasadena.drop('objectid',axis=1)

#appending pasadena to treesdf
treesdf = treesdf.append(pasadena)

# %%
#Cleaning the main df
#The col 'city' in the original datasets contains inconsistent information. It will be removed and replaced with data from 'whichcity'.
treesdf = treesdf.drop('city',axis=1)
treesdf['city'] = treesdf['whichcity'].str.replace(".geojson","")
treesdf = treesdf.drop('whichcity',axis=1)

# %%
#Overview of columns and size of dataframe
treesdf.info(verbose=True, null_counts=True)
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 1673610 entries, 0 to 71131
# Data columns (total 225 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   inventoryid          139884 non-null   float64
#  1   district             267675 non-null   object
#  2   address              668706 non-null   float64
#  3   fictitious           192187 non-null   object
#  4   street               527881 non-null   object
#  5   sidetype             258325 non-null   object
#  6   tree                 430634 non-null   float64
#  7   onaddress            278577 non-null   float64
#  8   onstreet             287995 non-null   object
#  9   species              1519523 non-null  object
#  10  botanical            469450 non-null   object
#  11  dbh                  575187 non-null   object
#  12  height               736006 non-null   object
#  13  parkwaytype          105215 non-null   object
#  14  geometry             1673610 non-null  geometry
#  15  botanicaln           358435 non-null   object
#  16  addr                 14830 non-null    object
#  17  addr2                15279 non-null    object
#  18  loc_type             14334 non-null    object
#  19  side                 237803 non-null   object
#  20  tree_count           15684 non-null    float64
#  21  com_name             15292 non-null    object
#  22  grid_id              15684 non-null    float64
#  23  trimmed              5052 non-null     object
#  24  sect_id              15684 non-null    float64
#  25  tree_id              15641 non-null    object
#  26  notes                6498 non-null     object
#  27  relocated            15684 non-null    float64
#  28  duplicate            15684 non-null    float64
#  29  inventoryi           263898 non-null   float64
#  30  speciesid            154180 non-null   float64
#  31  recommende           102362 non-null   object
#  32  parkway              253122 non-null   float64
#  33  utility              178977 non-null   object
#  34  sidewalkda           37067 non-null    object
#  35  datemodifi           102362 non-null   object
#  36  priority             100157 non-null   object
#  37  treecondit           100227 non-null   object
#  38  parkwaytyp           98895 non-null    object
#  39  actualdbh            133663 non-null   object
#  40  estimated_           47572 non-null    float64
#  41  maintenanc           20711 non-null    object
#  42  date                 20711 non-null    object
#  43  source               20711 non-null    object
#  44  isvalid              108597 non-null   object
#  45  sidewalkdamage       108597 non-null   float64
#  46  actualcrown          108597 non-null   float64
#  47  actualheight         108597 non-null   float64
#  48  estvalue             108597 non-null   float64
#  49  hassidewalkdamage    108597 non-null   object
#  50  isutility            108597 non-null   object
#  51  treeid               58901 non-null    float64
#  52  height_ran           40539 non-null    object
#  53  active               7009 non-null     float64
#  54  last_chang           7009 non-null     object
#  55  inspect_dt           7009 non-null     object
#  56  id                   240438 non-null   float64
#  57  inv_date             7009 non-null     object
#  58  uniqueid             7009 non-null     object
#  59  inspect_tm           7009 non-null     object
#  60  spp                  25553 non-null    object
#  61  dir                  7007 non-null     object
#  62  ext                  9301 non-null     object
#  63  ht                   7009 non-null     object
#  64  ca                   6876 non-null     object
#  65  cond                 7009 non-null     object
#  66  mt                   6877 non-null     object
#  67  ut                   7005 non-null     object
#  68  growtype             7005 non-null     object
#  69  growsize             7005 non-null     object
#  70  staff                7009 non-null     object
#  71  suffix               31 non-null       object
#  72  site                 16309 non-null    float64
#  73  onstr                7009 non-null     object
#  74  fromstr              7009 non-null     object
#  75  tostr                7009 non-null     object
#  76  x                    30916 non-null    float64
#  77  y                    30916 non-null    float64
#  78  optional1            11594 non-null    object
#  79  optional2            11594 non-null    object
#  80  optional3            0 non-null        object
#  81  optional4            22444 non-null    object
#  82  optional5            112 non-null      object
#  83  optional6            0 non-null        object
#  84  optional7            2323 non-null     object
#  85  optional8            3638 non-null     object
#  86  optional9            1562 non-null     object
#  87  optional10           0 non-null        object
#  88  optional11           0 non-null        object
#  89  optional12           0 non-null        object
#  90  optional13           0 non-null        object
#  91  optional14           0 non-null        object
#  92  optional15           0 non-null        object
#  93  common2              0 non-null        object
#  94  recommended          100124 non-null   object
#  95  treecondition        100124 non-null   object
#  96  recommendedpriority  91353 non-null    object
#  97  assetnumberexternal  100124 non-null   object
#  98  botanical_           37232 non-null    object
#  99  gisid                21858 non-null    float64
#  100 long                 21858 non-null    object
#  101 btncl_n              46763 non-null    object
#  102 cmmn_nm              46763 non-null    object
#  103 exct_db              46763 non-null    float64
#  104 prop_adr             124864 non-null   float64
#  105 prop_stree           0 non-null        object
#  106 condition            141188 non-null   object
#  107 diameter             96053 non-null    float64
#  108 exact_heig           119901 non-null   float64
#  109 genus                7448 non-null     object
#  110 genus_c              7448 non-null     object
#  111 geom                 0 non-null        object
#  112 dist                 13584 non-null    object
#  113 onadd                13584 non-null    float64
#  114 on_                  13584 non-null    object
#  115 dbh_range            13584 non-null    object
#  116 exactdbh             13584 non-null    float64
#  117 rem_prior            13584 non-null    object
#  118 pkwy_type            13584 non-null    object
#  119 pkwy                 13584 non-null    float64
#  120 pshb_borer           13584 non-null    object
#  121 border_tre           13584 non-null    object
#  122 comment              13584 non-null    object
#  123 label                13584 non-null    object
#  124 id2                  9419 non-null     object
#  125 property             25928 non-null    object
#  126 proper12             9508 non-null     float64
#  127 area                 8482 non-null     object
#  128 location             8481 non-null     object
#  129 unit                 9508 non-null     float64
#  130 on_adr               9436 non-null     float64
#  131 propst18             8357 non-null     object
#  132 botani8d             9477 non-null     object
#  133 exact_a2             9049 non-null     object
#  134 exact_f1             4078 non-null     float64
#  135 condita7             9285 non-null     object
#  136 gpsdate              9166 non-null     object
#  137 tvalue               4043 non-null     float64
#  138 fictit3              4038 non-null     float64
#  139 sidewalk             4043 non-null     float64
#  140 uuser                9416 non-null     object
#  141 udate                9419 non-null     object
#  142 status               9505 non-null     float64
#  143 recmaint             9117 non-null     object
#  144 recver               9403 non-null     float64
#  145 pkwy_tec             937 non-null      object
#  146 pkwy_se5             4048 non-null     float64
#  147 targetd              6400 non-null     object
#  148 datafile             937 non-null      object
#  149 point_x              4048 non-null     float64
#  150 point_y              4048 non-null     float64
#  151 addrid               4044 non-null     float64
#  152 rspecies             4043 non-null     float64
#  153 trunks               4043 non-null     float64
#  154 crown                4044 non-null     float64
#  155 hardsc8b             693 non-null      object
#  156 parkwa1a             9507 non-null     float64
#  157 parkwa2b             9500 non-null     object
#  158 righto4              4043 non-null     float64
#  159 inspec9f             9409 non-null     object
#  160 inspecb7             9457 non-null     object
#  161 colleca7             9381 non-null     object
#  162 treetag              0 non-null        object
#  163 historf2             34 non-null       float64
#  164 _symbo24             75 non-null       object
#  165 draw_tcf             89 non-null       float64
#  166 botanicalna          16583 non-null    object
#  167 treeconditi          16583 non-null    object
#  168 propstreet           106281 non-null   object
#  169 exact_dbh            112453 non-null   float64
#  170 pshb/borers          8771 non-null     object
#  171 ogc_fid              35235 non-null    float64
#  172 customer_t           35235 non-null    float64
#  173 dbhid                35235 non-null    float64
#  174 heightid             35235 non-null    float64
#  175 addresscon           35235 non-null    object
#  176 recommend            35235 non-null    float64
#  177 dbh__in_             35235 non-null    float64
#  178 height__in           35235 non-null    float64
#  179 estimatedv           35235 non-null    float64
#  180 recommen_1           35235 non-null    object
#  181 ghg_tree__           35235 non-null    object
#  182 st_seg               29383 non-null    object
#  183 place                35235 non-null    object
#  184 common_name          16459 non-null    object
#  185 botanical_name       16459 non-null    object
#  186 canopy               20928 non-null    object
#  187 rootpruning          20928 non-null    object
#  188 signclearance        20928 non-null    object
#  189 pshb/insects         20928 non-null    object
#  190 comments             20928 non-null    object
#  191 field_11             0 non-null        object
#  192 field_12             0 non-null        object
#  193 field_13             0 non-null        object
#  194 field_14             0 non-null        object
#  195 field_15             0 non-null        object
#  196 field_16             0 non-null        object
#  197 field_17             0 non-null        object
#  198 field_18             0 non-null        object
#  199 field_19             0 non-null        object
#  200 field_20             0 non-null        object
#  201 field_21             0 non-null        object
#  202 field_22             0 non-null        object
#  203 field_23             0 non-null        object
#  204 field_24             0 non-null        object
#  205 field_25             0 non-null        object
#  206 field_26             0 non-null        object
#  207 field_27             0 non-null        object
#  208 field_28             0 non-null        object
#  209 field_29             0 non-null        object
#  210 field_30             0 non-null        object
#  211 field_31             0 non-null        object
#  212 field_32             0 non-null        object
#  213 field_33             0 non-null        object
#  214 field_34             0 non-null        object
#  215 oid                  9066 non-null     float64
#  216 botname              36964 non-null    object
#  217 crownest             27898 non-null    object
#  218 house_numb           71111 non-null    float64
#  219 street_dir           33939 non-null    object
#  220 street_nam           71107 non-null    object
#  221 street_typ           71010 non-null    object
#  222 street_suf           0 non-null        object
#  223 trunk_diam           71017 non-null    float64
#  224 city                 1673610 non-null  object
# dtypes: float64(63), geometry(1), object(161)
# memory usage: 2.8+ GB

# %%
#Dropping columns that are empty
treesdf = treesdf.dropna(how='all', axis=1)

# %%
#Export trees file to a csv, which we will import during analysis. This will prevent Google Colab from using too much RAM, leading to crashes.
treesdf.to_csv('LAtrees.csv')
# !cp LAtrees.csv "/content/drive/My Drive/Public Trees - Wes/"
